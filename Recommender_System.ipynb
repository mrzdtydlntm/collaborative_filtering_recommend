# %%
from pyspark.sql import SparkSession
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS

# %%
spark = SparkSession.builder.appName('Recommender System CF').getOrCreate()

# %%
rat = spark.read.csv('datasets/rat.csv', inferSchema=True, header=True)

# %%
rat.printSchema()
# Out:
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- timestamp: integer (nullable = true)

# %%
data = rat.drop('timestamp')

# %%
data.show()
# Out:
# +------+-------+------+
# |userId|movieId|rating|
# +------+-------+------+
# |     1|     31|   2.5|
# |     1|   1029|   3.0|
# |     1|   1061|   3.0|
# |     1|   1129|   2.0|
# |     1|   1172|   4.0|
# |     1|   1263|   2.0|
# |     1|   1287|   2.0|
# |     1|   1293|   2.0|
# |     1|   1339|   3.5|
# |     1|   1343|   2.0|
# |     1|   1371|   2.5|
# |     1|   1405|   1.0|
# |     1|   1953|   4.0|
# |     1|   2105|   4.0|
# |     1|   2150|   3.0|
# |     1|   2193|   2.0|
# |     1|   2294|   2.0|
# |     1|   2455|   2.5|
# |     1|   2968|   1.0|
# |     1|   3671|   3.0|
# +------+-------+------+
# only showing top 20 rows

# %%
data.select(('rating')).describe().show()
# Out:
# +-------+------------------+
# |summary|            rating|
# +-------+------------------+
# |  count|            100004|
# |   mean| 3.543608255669773|
# | stddev|1.0580641091070326|
# |    min|               0.5|
# |    max|               5.0|
# +-------+------------------+

# %%
(training, test) = data.randomSplit([0.8, 0.2])

# %%
als = ALS(maxIter=5,regParam=0.01, userCol='userId', itemCol='movieId', ratingCol='rating')

# %%
model = als.fit(training)

# %%
predictions = model.transform(test)

# %%
predictions.show() #predictions user to rate movie
# Out:
# +------+-------+------+----------+
# |userId|movieId|rating|prediction|
# +------+-------+------+----------+
# |   534|    463|   4.0| 4.0021644|
# |    30|    463|   4.0|  2.989187|
# |   311|    463|   3.0| 3.0584733|
# |   602|    471|   3.0|  4.070516|
# |   292|    471|   3.5| 4.2181563|
# |   452|    471|   3.0| 3.5134454|
# |   607|    471|   4.0| 3.8449872|
# |   659|    471|   4.0| 2.9842432|
# |   537|    471|   5.0|   4.42451|
# |   574|    471|   3.5| 3.7981517|
# |   529|    471|   4.0|  3.234109|
# |   184|    471|   5.0| 4.4052963|
# |   311|    471|   0.5| 3.4139504|
# |   412|    833|   1.0| 2.3591518|
# |   294|    833|   2.0| 2.0872242|
# |   516|   1088|   3.0| 3.4330618|
# |    52|   1088|   4.0| 3.5411594|
# |    57|   1088|   4.0| 3.6720736|
# |   607|   1088|   2.0| 3.0233717|
# |   547|   1088|   5.0| 1.8062032|
# +------+-------+------+----------+
# only showing top 20 rows

# %%
mov = spark.read.csv('datasets/mov.csv', header=True, inferSchema=True)

# %%
res=predictions.join(mov, on=['movieId'], how='left')

# %%
res.show()
# Out:
# +-------+------+------+----------+--------------------+--------------------+
# |movieId|userId|rating|prediction|               title|              genres|
# +-------+------+------+----------+--------------------+--------------------+
# |    463|   534|   4.0| 4.0021644|Guilty as Sin (1993)|Crime|Drama|Thriller|
# |    463|    30|   4.0|  2.989187|Guilty as Sin (1993)|Crime|Drama|Thriller|
# |    463|   311|   3.0| 3.0584733|Guilty as Sin (1993)|Crime|Drama|Thriller|
# |    471|   602|   3.0|  4.070516|Hudsucker Proxy, ...|              Comedy|
# |    471|   292|   3.5| 4.2181563|Hudsucker Proxy, ...|              Comedy|
# |    471|   452|   3.0| 3.5134454|Hudsucker Proxy, ...|              Comedy|
# |    471|   607|   4.0| 3.8449872|Hudsucker Proxy, ...|              Comedy|
# |    471|   659|   4.0| 2.9842432|Hudsucker Proxy, ...|              Comedy|
# |    471|   537|   5.0|   4.42451|Hudsucker Proxy, ...|              Comedy|
# |    471|   574|   3.5| 3.7981517|Hudsucker Proxy, ...|              Comedy|
# |    471|   529|   4.0|  3.234109|Hudsucker Proxy, ...|              Comedy|
# |    471|   184|   5.0| 4.4052963|Hudsucker Proxy, ...|              Comedy|
# |    471|   311|   0.5| 3.4139504|Hudsucker Proxy, ...|              Comedy|
# |    833|   412|   1.0| 2.3591518|High School High ...|              Comedy|
# |    833|   294|   2.0| 2.0872242|High School High ...|              Comedy|
# |   1088|   516|   3.0| 3.4330618|Dirty Dancing (1987)|Drama|Musical|Rom...|
# |   1088|    52|   4.0| 3.5411594|Dirty Dancing (1987)|Drama|Musical|Rom...|
# |   1088|    57|   4.0| 3.6720736|Dirty Dancing (1987)|Drama|Musical|Rom...|
# |   1088|   607|   2.0| 3.0233717|Dirty Dancing (1987)|Drama|Musical|Rom...|
# |   1088|   547|   5.0| 1.8062032|Dirty Dancing (1987)|Drama|Musical|Rom...|
# +-------+------+------+----------+--------------------+--------------------+
# only showing top 20 rows

# %%
user_126 = res.filter(res['userId']==126).select(['userId', 'title', 'genres']) #get recommendation for user 126

# %%
user_564 = res.filter(res['userId']==564).select(['userId', 'title', 'genres']) #get recommendation for user 564

# %%
print('Recommendation Film for User 126')
user_126.show()
# Out:
# Recommendation Film for User 126
# +------+--------------------+--------------------+
# |userId|               title|              genres|
# +------+--------------------+--------------------+
# |   126|Silence of the La...|Crime|Horror|Thri...|
# |   126|    Toy Story (1995)|Adventure|Animati...|
# |   126|        Speed (1994)|Action|Romance|Th...|
# |   126|Jurassic Park (1993)|Action|Adventure|...|
# |   126| Broken Arrow (1996)|Action|Adventure|...|
# |   126|Beauty and the Be...|Animation|Childre...|
# |   126|       Batman (1989)|Action|Crime|Thri...|
# |   126|    Firm, The (1993)|      Drama|Thriller|
# |   126|Four Weddings and...|      Comedy|Romance|
# |   126|         I.Q. (1994)|      Comedy|Romance|
# +------+--------------------+--------------------+

# %%
print('Recommendation Film for User 564')
user_564.show()
# Out:
# Recommendation Film for User 564
# +------+--------------------+--------------------+
# |userId|               title|              genres|
# +------+--------------------+--------------------+
# |   564|   Local Hero (1983)|              Comedy|
# |   564|   Abyss, The (1989)|Action|Adventure|...|
# |   564|      Titanic (1997)|       Drama|Romance|
# |   564|Angela's Ashes (1...|               Drama|
# |   564|Running Man, The ...|       Action|Sci-Fi|
# |   564|Princess Caraboo ...|               Drama|
# |   564|Fear and Loathing...|Adventure|Comedy|...|
# |   564|Friday the 13th P...|              Horror|
# |   564|Allan Quatermain ...|Action|Adventure|...|
# |   564|   Jack Frost (1998)|Children|Comedy|D...|
# |   564|William Shakespea...|      Comedy|Fantasy|
# |   564|      Aladdin (1992)|Adventure|Animati...|
# |   564|She's the One (1996)|      Comedy|Romance|
# |   564| Pulp Fiction (1994)|Comedy|Crime|Dram...|
# |   564|Denise Calls Up (...|              Comedy|
# |   564|       Gloria (1999)|      Drama|Thriller|
# |   564| Pet Sematary (1989)|              Horror|
# |   564|  Dying Young (1991)|       Drama|Romance|
# |   564|     Maverick (1994)|Adventure|Comedy|...|
# |   564|Raiders of the Lo...|    Action|Adventure|
# +------+--------------------+--------------------+
# only showing top 20 rows

# %%
user_126.collect()
# Out:
# [Row(userId=126, title='Silence of the Lambs, The (1991)', genres='Crime|Horror|Thriller'),
#  Row(userId=126, title='Toy Story (1995)', genres='Adventure|Animation|Children|Comedy|Fantasy'),
#  Row(userId=126, title='Speed (1994)', genres='Action|Romance|Thriller'),
#  Row(userId=126, title='Jurassic Park (1993)', genres='Action|Adventure|Sci-Fi|Thriller'),
#  Row(userId=126, title='Broken Arrow (1996)', genres='Action|Adventure|Thriller'),
#  Row(userId=126, title='Beauty and the Beast (1991)', genres='Animation|Children|Fantasy|Musical|Romance|IMAX'),
#  Row(userId=126, title='Batman (1989)', genres='Action|Crime|Thriller'),
#  Row(userId=126, title='Firm, The (1993)', genres='Drama|Thriller'),
#  Row(userId=126, title='Four Weddings and a Funeral (1994)', genres='Comedy|Romance'),
#  Row(userId=126, title='I.Q. (1994)', genres='Comedy|Romance')]

# %%
user_564.collect()
# Out:
# [Row(userId=564, title='Local Hero (1983)', genres='Comedy'),
#  Row(userId=564, title='Abyss, The (1989)', genres='Action|Adventure|Sci-Fi|Thriller'),
#  Row(userId=564, title='Titanic (1997)', genres='Drama|Romance'),
#  Row(userId=564, title="Angela's Ashes (1999)", genres='Drama'),
#  Row(userId=564, title='Running Man, The (1987)', genres='Action|Sci-Fi'),
#  Row(userId=564, title='Princess Caraboo (1994)', genres='Drama'),
#  Row(userId=564, title='Fear and Loathing in Las Vegas (1998)', genres='Adventure|Comedy|Drama'),
#  Row(userId=564, title='Friday the 13th Part 2 (1981)', genres='Horror'),
#  Row(userId=564, title='Allan Quatermain and the Lost City of Gold (1987)', genres='Action|Adventure|Comedy'),
#  Row(userId=564, title='Jack Frost (1998)', genres='Children|Comedy|Drama'),
#  Row(userId=564, title="William Shakespeare's A Midsummer Night's Dream (1999)", genres='Comedy|Fantasy'),
#  Row(userId=564, title='Aladdin (1992)', genres='Adventure|Animation|Children|Comedy|Musical'),
#  Row(userId=564, title="She's the One (1996)", genres='Comedy|Romance'),
#  Row(userId=564, title='Pulp Fiction (1994)', genres='Comedy|Crime|Drama|Thriller'),
#  Row(userId=564, title='Denise Calls Up (1995)', genres='Comedy'),
#  Row(userId=564, title='Gloria (1999)', genres='Drama|Thriller'),
#  Row(userId=564, title='Pet Sematary (1989)', genres='Horror'),
#  Row(userId=564, title='Dying Young (1991)', genres='Drama|Romance'),
#  Row(userId=564, title='Maverick (1994)', genres='Adventure|Comedy|Western'),
#  Row(userId=564, title='Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', genres='Action|Adventure'),
#  Row(userId=564, title='Last Picture Show, The (1971)', genres='Drama'),
#  Row(userId=564, title='English Patient, The (1996)', genres='Drama|Romance|War'),
#  Row(userId=564, title='Young Guns (1988)', genres='Action|Comedy|Western'),
#  Row(userId=564, title='Bedknobs and Broomsticks (1971)', genres='Adventure|Children|Musical'),
#  Row(userId=564, title='Elephant Man, The (1980)', genres='Drama'),
#  Row(userId=564, title='Austin Powers: The Spy Who Shagged Me (1999)', genres='Action|Adventure|Comedy'),
#  Row(userId=564, title='Trees Lounge (1996)', genres='Drama'),
#  Row(userId=564, title='Tales from the Crypt Presents: Bordello of Blood (1996)', genres='Comedy|Horror'),
#  Row(userId=564, title="Pete's Dragon (1977)", genres='Adventure|Animation|Children|Musical'),
#  Row(userId=564, title='Aladdin and the King of Thieves (1996)', genres='Animation|Children|Comedy|Fantasy|Musical|Romance'),
#  Row(userId=564, title='Jerry Springer: Ringmaster (1998)', genres='Comedy|Drama'),
#  Row(userId=564, title='Screamers (1995)', genres='Action|Sci-Fi|Thriller'),
#  Row(userId=564, title='Star Trek VI: The Undiscovered Country (1991)', genres='Action|Mystery|Sci-Fi'),
#  Row(userId=564, title='Two Girls and a Guy (1997)', genres='Comedy|Drama'),
#  Row(userId=564, title='Bride of Re-Animator (1990)', genres='Comedy|Horror'),
#  Row(userId=564, title='Breaking Away (1979)', genres='Comedy|Drama'),
#  Row(userId=564, title='American Pop (1981)', genres='Animation|Musical'),
#  Row(userId=564, title='Harold and Maude (1971)', genres='Comedy|Drama|Romance'),
#  Row(userId=564, title='Cry in the Dark, A (1988)', genres='Drama'),
#  Row(userId=564, title='Cutting Edge, The (1992)', genres='Comedy|Drama|Romance'),
#  Row(userId=564, title='Losing Isaiah (1995)', genres='Drama'),
#  Row(userId=564, title='Spy Hard (1996)', genres='Comedy'),
#  Row(userId=564, title='American Buffalo (1996)', genres='Crime|Drama'),
#  Row(userId=564, title='Raise the Red Lantern (Da hong deng long gao gao gua) (1991)', genres='Drama'),
#  Row(userId=564, title='Inferno (1980)', genres='Horror'),
#  Row(userId=564, title='Near Dark (1987)', genres='Horror|Western'),
#  Row(userId=564, title='Client, The (1994)', genres='Drama|Mystery|Thriller'),
#  Row(userId=564, title='Beautiful Thing (1996)', genres='Drama|Romance'),
#  Row(userId=564, title='Battle for the Planet of the Apes (1973)', genres='Action|Sci-Fi'),
#  Row(userId=564, title='Clerks (1994)', genres='Comedy'),
#  Row(userId=564, title='Next Best Thing, The (2000)', genres='Comedy|Drama'),
#  Row(userId=564, title='Mr. Saturday Night (1992)', genres='Comedy|Drama'),
#  Row(userId=564, title='Apocalypse Now (1979)', genres='Action|Drama|War'),
#  Row(userId=564, title='Bedroom Window, The (1987)', genres='Thriller'),
#  Row(userId=564, title='Army of Darkness (1993)', genres='Action|Adventure|Comedy|Fantasy|Horror'),
#  Row(userId=564, title='Young Doctors in Love (1982)', genres='Comedy'),
#  Row(userId=564, title='Detroit Rock City (1999)', genres='Comedy'),
#  Row(userId=564, title='Story of Us, The (1999)', genres='Comedy|Drama'),
#  Row(userId=564, title='What Ever Happened to Baby Jane? (1962)', genres='Drama|Horror|Thriller'),
#  Row(userId=564, title='Circle of Friends (1995)', genres='Drama|Romance'),
#  Row(userId=564, title='Nothing to Lose (1994)', genres='Action|Crime|Drama'),
#  Row(userId=564, title='Fisher King, The (1991)', genres='Comedy|Drama|Fantasy|Romance'),
#  Row(userId=564, title='Unbearable Lightness of Being, The (1988)', genres='Drama'),
#  Row(userId=564, title='Borrowers, The (1997)', genres='Adventure|Children|Comedy|Fantasy'),
#  Row(userId=564, title='Rain Man (1988)', genres='Drama'),
#  Row(userId=564, title='Twin Falls Idaho (1999)', genres='Drama'),
#  Row(userId=564, title='Boomerang (1992)', genres='Comedy|Romance'),
#  Row(userId=564, title='Goodbye Girl, The (1977)', genres='Comedy|Romance'),
#  Row(userId=564, title='Faraway, So Close (In weiter Ferne, so nah!) (1993)', genres='Drama|Fantasy|Mystery|Romance'),
#  Row(userId=564, title='Princess Bride, The (1987)', genres='Action|Adventure|Comedy|Fantasy|Romance'),
#  Row(userId=564, title='Jackie Brown (1997)', genres='Crime|Drama|Thriller'),
#  Row(userId=564, title='Marnie (1964)', genres='Drama|Mystery|Romance|Thriller'),
#  Row(userId=564, title='Roadside Prophets (1992)', genres='Comedy|Drama'),
#  Row(userId=564, title='Lord of Illusions (1995)', genres='Horror'),
#  Row(userId=564, title='Miracle on 34th Street (1947)', genres='Comedy|Drama'),
#  Row(userId=564, title='Jade (1995)', genres='Thriller'),
#  Row(userId=564, title='Addiction, The (1995)', genres='Drama|Horror'),
#  Row(userId=564, title='Clockwork Orange, A (1971)', genres='Crime|Drama|Sci-Fi|Thriller'),
#  Row(userId=564, title='Net, The (1995)', genres='Action|Crime|Thriller'),
#  Row(userId=564, title='Trigger Effect, The (1996)', genres='Drama|Thriller'),
#  Row(userId=564, title='Slumber Party Massacre III (1990)', genres='Horror'),
#  Row(userId=564, title='Poison Ivy II (1996)', genres='Drama|Thriller'),
#  Row(userId=564, title='L.A. Story (1991)', genres='Comedy|Romance'),
#  Row(userId=564, title='Celluloid Closet, The (1995)', genres='Documentary'),
#  Row(userId=564, title='Event Horizon (1997)', genres='Horror|Sci-Fi|Thriller'),
#  Row(userId=564, title='Stigmata (1999)', genres='Drama|Thriller'),
#  Row(userId=564, title='Return of the Fly (1959)', genres='Horror|Sci-Fi'),
#  Row(userId=564, title='Good Mother, The (1988)', genres='Drama'),
#  Row(userId=564, title='Liar Liar (1997)', genres='Comedy'),
#  Row(userId=564, title='Insider, The (1999)', genres='Drama|Thriller'),
#  Row(userId=564, title='Godzilla (Gojira) (1954)', genres='Drama|Horror|Sci-Fi'),
#  Row(userId=564, title='Mummy, The (1932)', genres='Horror|Romance'),
#  Row(userId=564, title='Fast Times at Ridgemont High (1982)', genres='Comedy|Drama|Romance'),
#  Row(userId=564, title='Demolition Man (1993)', genres='Action|Adventure|Sci-Fi'),
#  Row(userId=564, title="Marvin's Room (1996)", genres='Drama'),
#  Row(userId=564, title='Police Academy 3: Back in Training (1986)', genres='Comedy|Crime'),
#  Row(userId=564, title='Presidio, The (1988)', genres='Action|Crime|Romance|Thriller'),
#  Row(userId=564, title="Concorde: Airport '79, The (1979)", genres='Drama'),
#  Row(userId=564, title='Someone to Watch Over Me (1987)', genres='Action|Crime|Thriller'),
#  Row(userId=564, title='Heat (1995)', genres='Action|Crime|Thriller'),
#  Row(userId=564, title='Casino (1995)', genres='Crime|Drama'),
#  Row(userId=564, title='Crocodile Dundee (1986)', genres='Adventure|Comedy'),
#  Row(userId=564, title='Arachnophobia (1990)', genres='Comedy|Horror'),
#  Row(userId=564, title='Set It Off (1996)', genres='Action|Crime'),
#  Row(userId=564, title='Candidate, The (1972)', genres='Drama'),
#  Row(userId=564, title='Urban Legends: Final Cut (2000)', genres='Horror'),
#  Row(userId=564, title='Howling, The (1980)', genres='Horror|Mystery'),
#  Row(userId=564, title='U Turn (1997)', genres='Crime|Drama|Mystery'),
#  Row(userId=564, title='Quatermass 2 (Enemy from Space) (1957)', genres='Sci-Fi|Thriller'),
#  Row(userId=564, title='Prom Night II (1987)', genres='Horror|Thriller'),
#  Row(userId=564, title='Firestarter (1984)', genres='Horror|Thriller'),
#  Row(userId=564, title='Bob Roberts (1992)', genres='Comedy'),
#  Row(userId=564, title='Vampire in Venice (Nosferatu a Venezia) (Nosferatu in Venice) (1986)', genres='Horror'),
#  Row(userId=564, title='Yes, Madam (a.k.a. Police Assassins) (a.k.a. In the Line of Duty 2) (Huang gu shi jie) (1985)', genres='Action'),
#  Row(userId=564, title='Angels in the Outfield (1994)', genres='Children|Comedy'),
#  Row(userId=564, title='Teenage Mutant Ninja Turtles II: The Secret of the Ooze (1991)', genres='Action|Children|Fantasy'),
#  Row(userId=564, title='Babe: Pig in the City (1998)', genres='Adventure|Children|Drama'),
#  Row(userId=564, title='Breakfast Club, The (1985)', genres='Comedy|Drama'),
#  Row(userId=564, title='Wizard of Oz, The (1939)', genres='Adventure|Children|Fantasy|Musical'),
#  Row(userId=564, title='Forever Young (1992)', genres='Drama|Romance|Sci-Fi'),
#  Row(userId=564, title='Drowning Mona (2000)', genres='Comedy'),
#  Row(userId=564, title='Asylum (1972)', genres='Horror'),
#  Row(userId=564, title='White Sands (1992)', genres='Drama|Thriller'),
#  Row(userId=564, title='Superman (1978)', genres='Action|Adventure|Sci-Fi'),
#  Row(userId=564, title='Shadow of a Doubt (1943)', genres='Crime|Drama|Thriller'),
#  Row(userId=564, title='Burnt Offerings (1976)', genres='Horror'),
#  Row(userId=564, title="Krippendorf's Tribe (1998)", genres='Comedy'),
#  Row(userId=564, title='Love Bug, The (1969)', genres='Children|Comedy'),
#  Row(userId=564, title='Indian Summer (a.k.a. Alive & Kicking) (1996)', genres='Comedy|Drama'),
#  Row(userId=564, title='Dark City (1998)', genres='Adventure|Film-Noir|Sci-Fi|Thriller'),
#  Row(userId=564, title='Children of the Corn II: The Final Sacrifice (1993)', genres='Horror'),
#  Row(userId=564, title='Blue Lagoon, The (1980)', genres='Adventure|Drama|Romance'),
#  Row(userId=564, title='Spy Who Loved Me, The (1977)', genres='Action|Adventure|Thriller'),
#  Row(userId=564, title='Beverly Hillbillies, The (1993)', genres='Comedy'),
#  Row(userId=564, title='Son in Law (1993)', genres='Comedy|Drama|Romance'),
#  Row(userId=564, title='Tombstone (1993)', genres='Action|Drama|Western'),
#  Row(userId=564, title='Nothing in Common (1986)', genres='Comedy'),
#  Row(userId=564, title='Encino Man (1992)', genres='Comedy'),
#  Row(userId=564, title='Bad Taste (1987)', genres='Comedy|Horror|Sci-Fi'),
#  Row(userId=564, title='Richard III (1995)', genres='Drama|War'),
#  Row(userId=564, title='Rear Window (1954)', genres='Mystery|Thriller'),
#  Row(userId=564, title='American Werewolf in London, An (1981)', genres='Comedy|Horror|Thriller'),
#  Row(userId=564, title='Amityville II: The Possession (1982)', genres='Horror'),
#  Row(userId=564, title='Friday the 13th Part VI: Jason Lives (1986)', genres='Horror'),
#  Row(userId=564, title='Gods Must Be Crazy, The (1980)', genres='Adventure|Comedy'),
#  Row(userId=564, title='Born Yesterday (1950)', genres='Comedy'),
#  Row(userId=564, title='Carnosaur 3: Primal Species (1996)', genres='Horror|Sci-Fi'),
#  Row(userId=564, title='Free Willy (1993)', genres='Adventure|Children|Drama'),
#  Row(userId=564, title='Sound of Music, The (1965)', genres='Musical|Romance'),
#  Row(userId=564, title='King Kong vs. Godzilla (Kingukongu tai Gojira) (1962)', genres='Action|Sci-Fi'),
#  Row(userId=564, title='Oscar and Lucinda (a.k.a. Oscar & Lucinda) (1997)', genres='Drama|Romance'),
#  Row(userId=564, title='Patriot Games (1992)', genres='Action|Crime|Drama|Thriller'),
#  Row(userId=564, title='Cutthroat Island (1995)', genres='Action|Adventure|Romance'),
#  Row(userId=564, title='Rumble in the Bronx (Hont faan kui) (1995)', genres='Action|Adventure|Comedy|Crime'),
#  Row(userId=564, title='Coma (1978)', genres='Thriller'),
#  Row(userId=564, title='Tank Girl (1995)', genres='Action|Comedy|Sci-Fi'),
#  Row(userId=564, title='Big Lebowski, The (1998)', genres='Comedy|Crime'),
#  Row(userId=564, title='Spirits of the Dead (1968)', genres='Horror|Mystery'),
#  Row(userId=564, title="Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994)", genres='Drama|Horror|Mystery|Thriller'),
#  Row(userId=564, title='Mosquito Coast, The (1986)', genres='Adventure|Drama|Thriller'),
#  Row(userId=564, title='Puppet Master 5: The Final Chapter (1994)', genres='Horror|Sci-Fi|Thriller'),
#  Row(userId=564, title="Jumpin' Jack Flash (1986)", genres='Action|Comedy|Romance|Thriller'),
#  Row(userId=564, title='Eye for an Eye (1996)', genres='Drama|Thriller'),
#  Row(userId=564, title='Right Stuff, The (1983)', genres='Drama'),
#  Row(userId=564, title='Vertigo (1958)', genres='Drama|Mystery|Romance|Thriller'),
#  Row(userId=564, title='EDtv (1999)', genres='Comedy'),
#  Row(userId=564, title='Surviving the Game (1994)', genres='Action|Adventure|Thriller'),
#  Row(userId=564, title="Jacob's Ladder (1990)", genres='Horror|Mystery'),
#  Row(userId=564, title='Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael Myers) (1995)', genres='Horror|Thriller'),
#  Row(userId=564, title='...And Justice for All (1979)', genres='Drama|Thriller'),
#  Row(userId=564, title="Child's Play (1988)", genres='Horror|Thriller'),
#  Row(userId=564, title='Wolf Man, The (1941)', genres='Drama|Fantasy|Horror'),
#  Row(userId=564, title='Summer of Sam (1999)', genres='Drama'),
#  Row(userId=564, title='Two Jakes, The (1990)', genres='Drama'),
#  Row(userId=564, title='Sum of Us, The (1994)', genres='Comedy|Drama'),
#  Row(userId=564, title='Gandhi (1982)', genres='Drama'),
#  Row(userId=564, title='Peter Pan (1953)', genres='Animation|Children|Fantasy|Musical'),
#  Row(userId=564, title="Nightmare on Elm Street 2: Freddy's Revenge, A (1985)", genres='Horror'),
#  Row(userId=564, title='Kids (1995)', genres='Drama'),
#  Row(userId=564, title='Low Down Dirty Shame, A (1994)', genres='Action|Comedy'),
#  Row(userId=564, title='When a Man Loves a Woman (1994)', genres='Drama|Romance'),
#  Row(userId=564, title='Loaded (1994)', genres='Drama|Thriller'),
#  Row(userId=564, title='Misery (1990)', genres='Drama|Horror|Thriller'),
#  Row(userId=564, title='Cabaret (1972)', genres='Drama|Musical'),
#  Row(userId=564, title='Emma (1996)', genres='Comedy|Drama|Romance'),
#  Row(userId=564, title='Rollercoaster (1977)', genres='Drama|Thriller'),
#  Row(userId=564, title='Blue Collar (1978)', genres='Crime|Drama'),
#  Row(userId=564, title='Slumber Party Massacre, The (1982)', genres='Horror'),
#  Row(userId=564, title='Species (1995)', genres='Horror|Sci-Fi'),
#  Row(userId=564, title="Dante's Peak (1997)", genres='Action|Thriller'),
#  Row(userId=564, title='Lone Star (1996)', genres='Drama|Mystery|Western'),
#  Row(userId=564, title='Wonderland (1997)', genres='Comedy|Documentary'),
#  Row(userId=564, title='True Crime (1999)', genres='Crime|Thriller'),
#  Row(userId=564, title='Kazaam (1996)', genres='Children|Comedy|Fantasy'),
#  Row(userId=564, title='Man with Two Brains, The (1983)', genres='Comedy'),
#  Row(userId=564, title='Cross of Iron (1977)', genres='War'),
#  Row(userId=564, title='Highlander: Endgame (Highlander IV) (2000)', genres='Action|Adventure|Fantasy'),
#  Row(userId=564, title='Crimson Tide (1995)', genres='Drama|Thriller|War'),
#  Row(userId=564, title='True Romance (1993)', genres='Crime|Thriller'),
#  Row(userId=564, title='Duck Soup (1933)', genres='Comedy|Musical|War'),
#  Row(userId=564, title='Night on Earth (1991)', genres='Comedy|Drama'),
#  Row(userId=564, title='Prom Night III: The Last Kiss (1989)', genres='Horror'),
#  Row(userId=564, title='Tarzan (1999)', genres='Adventure|Animation|Children|Drama'),
#  Row(userId=564, title='Clueless (1995)', genres='Comedy|Romance'),
#  Row(userId=564, title='Multiplicity (1996)', genres='Comedy'),
#  Row(userId=564, title='Scream 2 (1997)', genres='Comedy|Horror|Mystery|Thriller'),
#  Row(userId=564, title='Sling Blade (1996)', genres='Drama'),
#  Row(userId=564, title='Losing Chase (1996)', genres='Drama'),
#  Row(userId=564, title='Tex (1982)', genres='Drama'),
#  Row(userId=564, title='Madame Sousatzka (1988)', genres='Drama'),
#  Row(userId=564, title='Heavenly Creatures (1994)', genres='Crime|Drama'),
#  Row(userId=564, title='Exorcist II: The Heretic (1977)', genres='Horror'),
#  Row(userId=564, title='Heaven & Earth (1993)', genres='Action|Drama|War'),
#  Row(userId=564, title='Maximum Overdrive (1986)', genres='Horror'),
#  Row(userId=564, title='Sting, The (1973)', genres='Comedy|Crime'),
#  Row(userId=564, title='Fanny and Alexander (Fanny och Alexander) (1982)', genres='Drama|Fantasy|Mystery'),
#  Row(userId=564, title='Double Jeopardy (1999)', genres='Action|Crime|Drama|Thriller'),
#  Row(userId=564, title='Evil Dead II (Dead by Dawn) (1987)', genres='Action|Comedy|Fantasy|Horror'),
#  Row(userId=564, title='Children of the Corn III (1994)', genres='Horror'),
#  Row(userId=564, title='Death Wish (1974)', genres='Action|Crime|Drama'),
#  Row(userId=564, title='Twilight (1998)', genres='Crime|Drama|Thriller'),
#  Row(userId=564, title='Repo Man (1984)', genres='Comedy|Sci-Fi'),
#  Row(userId=564, title="Astronaut's Wife, The (1999)", genres='Horror|Sci-Fi|Thriller'),
#  Row(userId=564, title='Burglar (1987)', genres='Comedy|Crime'),
#  Row(userId=564, title='Star Trek: First Contact (1996)', genres='Action|Adventure|Sci-Fi|Thriller'),
#  Row(userId=564, title='Halloween 4: The Return of Michael Myers (1988)', genres='Horror'),
#  Row(userId=564, title='Public Access (1993)', genres='Drama|Thriller'),
#  Row(userId=564, title='Nightmare on Elm Street 3: Dream Warriors, A (1987)', genres='Horror|Thriller'),
#  Row(userId=564, title='And God Created Woman (1988)', genres='Comedy|Drama|Romance'),
#  Row(userId=564, title='Rushmore (1998)', genres='Comedy|Drama'),
#  Row(userId=564, title='End of Violence, The (1997)', genres='Drama|Thriller'),
#  Row(userId=564, title='Major Payne (1995)', genres='Comedy'),
#  Row(userId=564, title='Texas Chainsaw Massacre: The Next Generation (a.k.a. The Return of the Texas Chainsaw Massacre) (1994)', genres='Horror'),
#  Row(userId=564, title='Creature Comforts (1989)', genres='Animation|Comedy'),
#  Row(userId=564, title='Office Killer (1997)', genres='Thriller'),
#  Row(userId=564, title='Billy Madison (1995)', genres='Comedy'),
#  Row(userId=564, title='RoboCop 2 (1990)', genres='Action|Crime|Sci-Fi|Thriller'),
#  Row(userId=564, title='Lethal Weapon 4 (1998)', genres='Action|Comedy|Crime|Thriller'),
#  Row(userId=564, title='Deep Blue Sea (1999)', genres='Action|Horror|Sci-Fi|Thriller'),
#  Row(userId=564, title='Mighty Morphin Power Rangers: The Movie (1995)', genres='Action|Children'),
#  Row(userId=564, title='Police Academy (1984)', genres='Comedy|Crime'),
#  Row(userId=564, title='Dead Again (1991)', genres='Mystery|Romance|Thriller'),
#  Row(userId=564, title='Hideaway (1995)', genres='Thriller'),
#  Row(userId=564, title='Lords of Flatbush, The (1974)', genres='Comedy|Drama'),
#  Row(userId=564, title='Forget Paris (1995)', genres='Comedy|Romance'),
#  Row(userId=564, title='Drop Dead Fred (1991)', genres='Comedy|Fantasy'),
#  Row(userId=564, title='Teenage Mutant Ninja Turtles (1990)', genres='Action|Children|Comedy|Fantasy|Sci-Fi'),
#  Row(userId=564, title='Frequency (2000)', genres='Drama|Thriller'),
#  Row(userId=564, title='Velocity of Gary, The (1998)', genres='Comedy|Romance'),
#  Row(userId=564, title='Perfect Storm, The (2000)', genres='Drama|Thriller'),
#  Row(userId=564, title='Boys of St. Vincent, The (1992)', genres='Drama'),
#  Row(userId=564, title='Planet of the Apes (1968)', genres='Action|Drama|Sci-Fi'),
#  Row(userId=564, title='Hell Night (1981)', genres='Horror'),
#  Row(userId=564, title='Hidden, The (1987)', genres='Action|Horror|Sci-Fi'),
#  Row(userId=564, title='Come See the Paradise (1990)', genres='Drama|Romance'),
#  Row(userId=564, title='All Dogs Go to Heaven (1989)', genres='Animation|Children|Comedy|Drama|Fantasy'),
#  Row(userId=564, title='Adventures in Babysitting (1987)', genres='Adventure|Comedy'),
#  Row(userId=564, title='From Russia with Love (1963)', genres='Action|Adventure|Thriller'),
#  Row(userId=564, title='Caligula (1979)', genres='Drama'),
#  Row(userId=564, title='Dragonheart (1996)', genres='Action|Adventure|Fantasy'),
#  Row(userId=564, title='Michael (1996)', genres='Comedy|Drama|Fantasy|Romance'),
#  Row(userId=564, title='Conan the Barbarian (1982)', genres='Action|Adventure|Fantasy'),
#  Row(userId=564, title='Poison Ivy: New Seduction (1997)', genres='Drama|Thriller'),
#  Row(userId=564, title='Threesome (1994)', genres='Comedy|Romance'),
#  Row(userId=564, title='Grifters, The (1990)', genres='Crime|Drama|Film-Noir'),
#  Row(userId=564, title='Frenzy (1972)', genres='Thriller'),
#  Row(userId=564, title='Poison Ivy (1992)', genres='Drama|Thriller'),
#  Row(userId=564, title='Some Folks Call It a Sling Blade (1993)', genres='Drama|Thriller'),
#  Row(userId=564, title='My Left Foot (1989)', genres='Drama'),
#  Row(userId=564, title='Apple Dumpling Gang Rides Again, The (1979)', genres='Children|Comedy|Western'),
#  Row(userId=564, title='Beauty and the Beast (1991)', genres='Animation|Children|Fantasy|Musical|Romance|IMAX'),
#  Row(userId=564, title='Bad Moon (1996)', genres='Action|Adventure|Horror'),
#  Row(userId=564, title='Strictly Ballroom (1992)', genres='Comedy|Romance'),
#  Row(userId=564, title='Tales from the Darkside: The Movie (1990)', genres='Fantasy|Horror|Thriller'),
#  Row(userId=564, title='Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', genres='Mystery|Sci-Fi|Thriller'),
#  Row(userId=564, title='Pollyanna (1960)', genres='Children|Comedy|Drama'),
#  Row(userId=564, title='Howard the Duck (1986)', genres='Adventure|Comedy|Sci-Fi'),
#  Row(userId=564, title='Sleepy Hollow (1999)', genres='Fantasy|Horror|Mystery|Romance'),
#  Row(userId=564, title='H.O.T.S. (1979)', genres='Comedy'),
#  Row(userId=564, title='House of the Spirits, The (1993)', genres='Drama|Romance'),
#  Row(userId=564, title='Stop! Or My Mom Will Shoot (1992)', genres='Action|Comedy'),
#  Row(userId=564, title="Can't Hardly Wait (1998)", genres='Comedy|Drama|Romance'),
#  Row(userId=564, title='Rob Roy (1995)', genres='Action|Drama|Romance|War'),
#  Row(userId=564, title='Double Happiness (1994)', genres='Drama'),
#  Row(userId=564, title="It's a Wonderful Life (1946)", genres='Children|Drama|Fantasy|Romance'),
#  Row(userId=564, title="Darby O'Gill and the Little People (1959)", genres='Adventure|Children|Fantasy'),
#  Row(userId=564, title='Honeymoon in Vegas (1992)', genres='Comedy|Romance'),
#  Row(userId=564, title='Speechless (1994)', genres='Comedy|Romance'),
#  Row(userId=564, title='Return to Oz (1985)', genres='Adventure|Children|Fantasy'),
#  Row(userId=564, title='Red Sonja (1985)', genres='Action|Adventure|Fantasy'),
#  Row(userId=564, title='Roommates (1995)', genres='Comedy|Drama'),
#  Row(userId=564, title='Simple Twist of Fate, A (1994)', genres='Drama'),
#  Row(userId=564, title='Hunchback of Notre Dame, The (1996)', genres='Animation|Children|Drama|Musical|Romance'),
#  Row(userId=564, title='Westworld (1973)', genres='Action|Sci-Fi|Thriller|Western'),
#  Row(userId=564, title='Licence to Kill (1989)', genres='Action|Adventure|Thriller'),
#  Row(userId=564, title='Birdy (1984)', genres='Drama|War'),
#  Row(userId=564, title='Gods Must Be Crazy II, The (1989)', genres='Comedy'),
#  Row(userId=564, title='Night Shift (1982)', genres='Comedy'),
#  Row(userId=564, title='Total Recall (1990)', genres='Action|Adventure|Sci-Fi|Thriller'),
#  Row(userId=564, title='Dog Day Afternoon (1975)', genres='Crime|Drama'),
#  Row(userId=564, title='Fox and the Hound, The (1981)', genres='Animation|Children|Drama'),
#  Row(userId=564, title='Fair Game (1995)', genres='Action'),
#  Row(userId=564, title='Star Wars: Episode IV - A New Hope (1977)', genres='Action|Adventure|Sci-Fi'),
#  Row(userId=564, title='Basketball Diaries, The (1995)', genres='Drama'),
#  Row(userId=564, title='Some Like It Hot (1959)', genres='Comedy|Crime'),
#  Row(userId=564, title='Strange Days (1995)', genres='Action|Crime|Drama|Mystery|Sci-Fi|Thriller'),
#  Row(userId=564, title='Santa Clause, The (1994)', genres='Comedy|Drama|Fantasy'),
#  Row(userId=564, title="Muriel's Wedding (1994)", genres='Comedy'),
#  Row(userId=564, title='That Darn Cat! (1965)', genres='Children|Comedy|Mystery'),
#  Row(userId=564, title='Diva (1981)', genres='Action|Drama|Mystery|Romance|Thriller'),
#  Row(userId=564, title='Hoosiers (a.k.a. Best Shot) (1986)', genres='Drama|Romance'),
#  Row(userId=564, title='Dreamscape (1984)', genres='Horror|Sci-Fi|Thriller'),
#  Row(userId=564, title='Alive (1993)', genres='Drama'),
#  Row(userId=564, title='Curse of the Puppet Master (Puppet Master 6: The Curse) (1998)', genres='Horror|Sci-Fi|Thriller'),
#  Row(userId=564, title='Female Perversions (1996)', genres='Drama'),
#  Row(userId=564, title='Goonies, The (1985)', genres='Action|Adventure|Children|Comedy|Fantasy'),
#  Row(userId=564, title='Addams Family, The (1991)', genres='Children|Comedy|Fantasy'),
#  Row(userId=564, title='Jack (1996)', genres='Comedy|Drama'),
#  Row(userId=564, title='NeverEnding Story II: The Next Chapter, The (1990)', genres='Adventure|Children|Fantasy'),
#  Row(userId=564, title='Extremities (1986)', genres='Drama|Thriller'),
#  Row(userId=564, title='Backdraft (1991)', genres='Action|Drama'),
#  Row(userId=564, title='Single White Female (1992)', genres='Drama|Thriller'),
#  Row(userId=564, title='Hellraiser (1987)', genres='Horror'),
#  Row(userId=564, title='Sorority House Massacre II (1990)', genres='Horror'),
#  Row(userId=564, title='Indiana Jones and the Temple of Doom (1984)', genres='Action|Adventure|Fantasy'),
#  Row(userId=564, title='Beach Party (1963)', genres='Comedy'),
#  Row(userId=564, title='8 Heads in a Duffel Bag (1997)', genres='Comedy'),
#  Row(userId=564, title='Friday the 13th Part VIII: Jason Takes Manhattan (1989)', genres='Horror'),
#  Row(userId=564, title="Charlotte's Web (1973)", genres='Animation|Children'),
#  Row(userId=564, title='Under the Rainbow (1981)', genres='Comedy'),
#  Row(userId=564, title='Swan Princess, The (1994)', genres='Animation|Children'),
#  Row(userId=564, title="McHale's Navy (1997)", genres='Comedy|War'),
#  Row(userId=564, title='Spaceballs (1987)', genres='Comedy|Sci-Fi'),
#  Row(userId=564, title='Lawnmower Man 2: Beyond Cyberspace (1996)', genres='Action|Sci-Fi|Thriller'),
#  Row(userId=564, title='Nine Months (1995)', genres='Comedy|Romance'),
#  Row(userId=564, title='Dr. No (1962)', genres='Action|Adventure|Thriller'),
#  Row(userId=564, title='Being John Malkovich (1999)', genres='Comedy|Drama|Fantasy'),
#  Row(userId=564, title="Christmas Vacation (National Lampoon's Christmas Vacation) (1989)", genres='Comedy'),
#  Row(userId=564, title='Virus (1999)', genres='Horror|Sci-Fi'),
#  Row(userId=564, title='Addams Family Values (1993)', genres='Children|Comedy|Fantasy'),
#  Row(userId=564, title='Witness (1985)', genres='Drama|Romance|Thriller'),
#  Row(userId=564, title='Strangers on a Train (1951)', genres='Crime|Drama|Film-Noir|Thriller'),
#  Row(userId=564, title='Glen or Glenda (1953)', genres='Drama'),
#  Row(userId=564, title='Problem Child 2 (1991)', genres='Comedy'),
#  Row(userId=564, title='Arthur (1981)', genres='Comedy|Romance'),
#  Row(userId=564, title='Wife, The (1995)', genres='Comedy|Drama'),
#  Row(userId=564, title='Rich and Strange (1931)', genres='Comedy|Romance'),
#  Row(userId=564, title='Pecker (1998)', genres='Comedy|Drama'),
#  Row(userId=564, title='Nightmare Before Christmas, The (1993)', genres='Animation|Children|Fantasy|Musical'),
#  Row(userId=564, title='Jawbreaker (1999)', genres='Comedy'),
#  Row(userId=564, title='Mommie Dearest (1981)', genres='Drama'),
#  Row(userId=564, title='Bringing Out the Dead (1999)', genres='Drama'),
#  Row(userId=564, title='Basquiat (1996)', genres='Drama'),
#  Row(userId=564, title='Parent Trap, The (1961)', genres='Children|Comedy|Romance'),
#  Row(userId=564, title='Driving Miss Daisy (1989)', genres='Drama'),
#  Row(userId=564, title='Impostors, The (1998)', genres='Comedy'),
#  Row(userId=564, title="Logan's Run (1976)", genres='Action|Adventure|Sci-Fi'),
#  Row(userId=564, title='Wallace & Gromit: A Close Shave (1995)', genres='Animation|Children|Comedy'),
#  Row(userId=564, title='History of the World: Part I (1981)', genres='Comedy|Musical'),
#  Row(userId=564, title='In the Name of the Father (1993)', genres='Drama'),
#  Row(userId=564, title='Deep Rising (1998)', genres='Action|Horror|Sci-Fi'),
#  Row(userId=564, title='1984 (Nineteen Eighty-Four) (1984)', genres='Drama|Sci-Fi'),
#  Row(userId=564, title='Bed of Roses (1996)', genres='Drama|Romance'),
#  Row(userId=564, title='Shining, The (1980)', genres='Horror'),
#  Row(userId=564, title='Englishman Who Went Up a Hill But Came Down a Mountain, The (1995)', genres='Comedy|Romance'),
#  Row(userId=564, title='Heartburn (1986)', genres='Comedy|Drama'),
#  Row(userId=564, title='Barry Lyndon (1975)', genres='Drama|Romance|War'),
#  Row(userId=564, title='Escape to Witch Mountain (1975)', genres='Adventure|Children|Fantasy'),
#  Row(userId=564, title='Waterworld (1995)', genres='Action|Adventure|Sci-Fi'),
#  Row(userId=564, title='Emerald Forest, The (1985)', genres='Action|Adventure|Drama'),
#  Row(userId=564, title='Turtle Diary (1985)', genres='Comedy|Drama|Romance'),
#  Row(userId=564, title='Soapdish (1991)', genres='Comedy'),
#  Row(userId=564, title='Nick of Time (1995)', genres='Action|Thriller')]
